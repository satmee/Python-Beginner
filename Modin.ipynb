# %% [markdown]
# In pandas, you are only able to use one core at a time when you are doing computation of any kind. With Modin, you are able to use all of the CPU cores on your machine.

# %%
pip install modin[all]
# Out:
# Requirement already satisfied: modin[all] in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (0.12.1)
# Requirement already satisfied: packaging in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (24.0)
# Requirement already satisfied: fsspec in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (2023.1.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (1.21.6)
# Requirement already satisfied: pandas==1.3.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (1.3.5)
# Requirement already satisfied: pyarrow>=1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (12.0.1)
# Collecting rpyc==4.1.5
#   Downloading rpyc-4.1.5-py3-none-any.whl (68 kB)
#      -------------------------------------- 68.9/68.9 kB 752.2 kB/s eta 0:00:00
# Collecting modin-spreadsheet>=0.1.0
#   Downloading modin_spreadsheet-0.1.2-py2.py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 4.6 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting dask>=2.22.0
#   Downloading dask-2022.2.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 2.7 MB/s eta 0:00:00
# Collecting distributed>=2.22.0
#   Downloading distributed-2022.2.0-py3-none-any.whl (837 kB)
#      -------------------------------------- 837.0/837.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: ray[default]>=1.4.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin[all]) (2.7.2)
# Collecting boto3
#   Downloading boto3-1.33.13-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.3/139.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from pandas==1.3.5->modin[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from pandas==1.3.5->modin[all]) (2024.1)
# Collecting plumbum
#   Downloading plumbum-1.8.2-py3-none-any.whl (127 kB)
#      -------------------------------------- 127.0/127.0 kB 1.9 MB/s eta 0:00:00
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0.1-cp37-cp37m-win_amd64.whl (153 kB)
#      -------------------------------------- 153.2/153.2 kB 2.3 MB/s eta 0:00:00
# Collecting partd>=0.3.10
#   Downloading partd-1.4.1-py3-none-any.whl (18 kB)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (3.1.3)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting tblib>=1.6.0
#   Downloading tblib-2.0.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: msgpack>=0.6.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (1.0.5)
# Requirement already satisfied: psutil>=5.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (5.9.8)
# Requirement already satisfied: click>=6.6 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (7.1.2)
# Collecting zict>=0.1.3
#   Downloading zict-2.2.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: tornado>=5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (6.2)
# Requirement already satisfied: setuptools in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from distributed>=2.22.0->modin[all]) (41.2.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (8.1.2)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (1.0.0)
# Requirement already satisfied: notebook>=6.0.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from modin-spreadsheet>=0.1.0->modin[all]) (6.5.6)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (2.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (4.24.4)
# Requirement already satisfied: aiosignal in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (1.3.1)
# Requirement already satisfied: frozenlist in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (1.3.3)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (4.7.1)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (3.12.2)
# Requirement already satisfied: jsonschema in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (4.17.3)
# Requirement already satisfied: virtualenv<20.21.1,>=20.0.24 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (20.21.0)
# Requirement already satisfied: py-spy>=0.2.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (0.3.14)
# Requirement already satisfied: grpcio>=1.32.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (1.62.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (0.17.1)
# Requirement already satisfied: pydantic<2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (1.10.14)
# Requirement already satisfied: colorful in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (0.5.6)
# Requirement already satisfied: opencensus in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (0.11.4)
# Requirement already satisfied: aiohttp>=3.7 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (3.8.6)
# Requirement already satisfied: aiohttp-cors in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (0.7.0)
# Requirement already satisfied: gpustat>=1.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (1.1.1)
# Requirement already satisfied: smart-open in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ray[default]>=1.4.0->modin[all]) (7.0.4)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.34.0,>=1.33.13
#   Downloading botocore-1.33.13-py3-none-any.whl (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 2.2 MB/s eta 0:00:00
# Collecting s3transfer<0.9.0,>=0.8.2
#   Downloading s3transfer-0.8.2-py3-none-any.whl (82 kB)
#      -------------------------------------- 82.0/82.0 kB 574.4 kB/s eta 0:00:00
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (4.0.3)
# Requirement already satisfied: asynctest==0.13.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (23.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (3.3.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from aiohttp>=3.7->ray[default]>=1.4.0->modin[all]) (1.9.4)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from botocore<1.34.0,>=1.33.13->boto3->modin[all]) (1.25.9)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from gpustat>=1.0.0->ray[default]>=1.4.0->modin[all]) (12.535.133)
# Requirement already satisfied: blessed>=1.17.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from gpustat>=1.0.0->ray[default]>=1.4.0->modin[all]) (1.20.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.10)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.0.10)
# Requirement already satisfied: comm>=0.1.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.9.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (7.34.0)
# Requirement already satisfied: ipykernel in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.16.2)
# Requirement already satisfied: nbconvert in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (7.6.0)
# Requirement already satisfied: qtconsole in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.4.4)
# Requirement already satisfied: jupyter-console in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.6.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.8.2)
# Requirement already satisfied: nbformat in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (5.8.0)
# Requirement already satisfied: ipython-genutils in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: pyzmq<25,>=17 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (24.0.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (4.12.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.6.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (7.4.9)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.0.0)
# Requirement already satisfied: argon2-cffi in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (23.1.0)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.5->modin[all]) (1.16.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.4.0->modin[all]) (3.11.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.4.0->modin[all]) (6.7.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]>=1.4.0->modin[all]) (0.3.8)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from colorful->ray[default]>=1.4.0->modin[all]) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jinja2->distributed>=2.22.0->modin[all]) (2.1.5)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jsonschema->ray[default]>=1.4.0->modin[all]) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jsonschema->ray[default]>=1.4.0->modin[all]) (0.19.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jsonschema->ray[default]>=1.4.0->modin[all]) (5.12.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from opencensus->ray[default]>=1.4.0->modin[all]) (2.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from opencensus->ray[default]>=1.4.0->modin[all]) (0.1.3)
# Requirement already satisfied: pywin32 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from plumbum->rpyc==4.1.5->modin[all]) (306)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from requests->ray[default]>=1.4.0->modin[all]) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from requests->ray[default]>=1.4.0->modin[all]) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from requests->ray[default]>=1.4.0->modin[all]) (3.0.4)
# Requirement already satisfied: wrapt in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from smart-open->ray[default]>=1.4.0->modin[all]) (1.16.0)
# Requirement already satisfied: jinxed>=1.1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]>=1.4.0->modin[all]) (1.2.1)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]>=1.4.0->modin[all]) (0.2.13)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (2.29.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (1.23.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from importlib-metadata>=4.8.3->virtualenv<20.21.1,>=20.0.24->ray[default]>=1.4.0->modin[all]) (3.15.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.43)
# Requirement already satisfied: backcall in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.19.1)
# Requirement already satisfied: pygments in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.17.2)
# Requirement already satisfied: matplotlib-inline in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.5)
# Requirement already satisfied: decorator in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (5.1.1)
# Requirement already satisfied: entrypoints in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client<8,>=5.3.4->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.4)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (0.2.4)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (4.12.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.5.1)
# Requirement already satisfied: defusedxml in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.7.1)
# Requirement already satisfied: tinycss2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.2.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.2.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (6.0.0)
# Requirement already satisfied: fastjsonschema in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from nbformat->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.19.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from terminado>=0.8.3->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from ipykernel->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (1.7.0)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from qtconsole->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.5.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (4.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->modin-spreadsheet>=0.1.0->modin[all]) (0.8.3)
# Requirement already satisfied: ansicon in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jinxed>=1.1.0->blessed>=1.17.1->gpustat>=1.0.0->ray[default]>=1.4.0->modin[all]) (1.89.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (3.7.1)
# Requirement already satisfied: websocket-client in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.6.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->modin-spreadsheet>=0.1.0->modin[all]) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.3.1)
# Requirement already satisfied: exceptiongroup in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0.3->modin-spreadsheet>=0.1.0->modin[all]) (2.21)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]>=1.4.0->modin[all]) (0.5.1)
# Installing collected packages: sortedcontainers, heapdict, zict, toolz, tblib, pyyaml, plumbum, locket, jmespath, cloudpickle, rpyc, partd, botocore, s3transfer, dask, distributed, boto3, modin-spreadsheet
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-uninstall-h2b8o788\\_yaml.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd

# %%
# %%time
df = pd.read_csv(r'C:\Users\lenovo\Downloads\titanic_train.csv')
df
# Out:
# Wall time: 6.97 ms
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# %%time
df['Ticket'].count()
# Out:
# Wall time: 1.01 ms
# 891

# %%
import modin.pandas as pd

# %%
# %%time
df = pd.read_csv('titanic_train.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\modin\pandas\io.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     133     _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     134     kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 135     return _read(**kwargs)
#     136
#     137
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\modin\pandas\io.py in _read(**kwargs)
#      56     from modin.core.execution.dispatching.factories.dispatcher import FactoryDispatcher
#      57
# ---> 58     Engine.subscribe(_update_engine)
#      59     squeeze = kwargs.pop("squeeze", False)
#      60     pd_obj = FactoryDispatcher.read_csv(**kwargs)
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\modin\config\pubsub.py in subscribe(cls, callback)
#     211         """
#     212         cls._subs.append(callback)
# --> 213         callback(cls)
#     214
#     215     @classmethod
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\modin\pandas\__init__.py in _update_engine(publisher)
#     125             from modin.core.execution.ray.common.utils import initialize_ray
#     126
# --> 127             initialize_ray()
#     128     elif publisher.get() == "Native":
#     129         # With OmniSci storage format there is only a single worker per node
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\modin\core\execution\ray\common\utils.py in initialize_ray(override_is_cluster, override_redis_address, override_redis_password)
#     198                     GPU_MANAGERS.append(GPUManager.remote(i))
#     199     _move_stdlib_ahead_of_site_packages()
# --> 200     ray.worker.global_worker.run_function_on_all_workers(
#     201         _move_stdlib_ahead_of_site_packages
#     202     )
#
# AttributeError: 'Worker' object has no attribute 'run_function_on_all_workers'
